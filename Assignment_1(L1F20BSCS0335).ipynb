# %% [markdown]
# # NAME:             Muhammad Bilal Nawaz
# # REG:                L1F20BSCS0335
# # SECTION:        D2

# %% [markdown]
# # QUESTION 1

# %%
# importing the pandas library to read data in data frame
import pandas as pd
df=pd.read_csv('jsrt_metadata.csv')
import numpy as np
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
# checking if the file has missing values.
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
# replacing the missing values of quatitative data with mean.
mean=df['subtlety'].astype('float').mean()
mean=int(mean)
mean
# Out:
# 2

# %%
df['subtlety'].replace(np.nan,mean,inplace=True)

# %%
df['state'].replace('non-nodule',np.nan,inplace=True)
minimum=df['state'].value_counts().idxmin()
df['state'].replace(np.nan,minimum,inplace=True)
df
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 242  JPCNN089.png       2.0   NaN  50    Male     NaN     NaN     benign
# 243  JPCNN090.png       2.0   NaN  68  Female     NaN     NaN     benign
# 244  JPCNN091.png       2.0   NaN  81    Male     NaN     NaN     benign
# 245  JPCNN092.png       2.0   NaN  70  Female     NaN     NaN     benign
# 246  JPCNN093.png       2.0   NaN  41    Male     NaN     NaN     benign
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# ...

# %%
# replacing the missing values of quatitative data with mean and qualitative data with minimum or maximum repeated data value.
mean=df['size'].astype('float').mean()
mean=int(mean)
df['size'].replace(np.nan,mean,inplace=True)
mean=df['x'].astype('float').mean()
mean=int(mean)
df['y'].replace(np.nan,mean,inplace=True)
mean=df['y'].astype('float').mean()
mean=int(mean)
df['x'].replace(np.nan,mean,inplace=True)
maximum=df['position'].value_counts().idxmax()
maximum
df['position'].replace(np.nan,maximum,inplace=True)
minimum=df['diagnosis'].value_counts().idxmin()
minimum
df['diagnosis'].replace(np.nan,minimum,inplace=True)
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 242  JPCNN089.png       2.0  17.0  50    Male   894.0   937.0     benign
# 243  JPCNN090.png       2.0  17.0  68  Female   894.0   937.0     benign
# 244  JPCNN091.png       2.0  17.0  81    Male   894.0   937.0     benign
# 245  JPCNN092.png       2.0  17.0  70  Female   894.0   937.0     benign
# 246  JPCNN093.png       2.0  17.0  41    Male   894.0   937.0     benign
#
#                position                          diagnosis
# ...

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
# importing matplotlib to draw graphs and charts.
import matplotlib as plt
from matplotlib import pyplot

# %%
#finding each diesease pateint number and saving it into the another list
total_patient=df['diagnosis'].value_counts()
diseases_name=df['diagnosis'].value_counts().index.tolist()
total_patient
# Out:
# lung cancer(large cell carcinoma)                 94
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# unknown                                            4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Inflammatory mass                                  2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# hamartoma                                          2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# sclerosing hemangioma                              2
# ...

# %%
# ploting histogram:
plt.pyplot.figure(figsize=(21,21),facecolor='lightgrey',edgecolor='purple')
plt.pyplot.xlabel('DISEASE')
plt.pyplot.ylabel('NUMBER OF PATIENT')
plt.pyplot.title('PATIENTS OF EACH DISEASE')
plt.pyplot.hist(df['diagnosis'],color='lightblue',ec='black')
# Out:
# (array([74., 33., 13.,  5.,  8.,  7.,  3., 96.,  4.,  4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # QUESTION 2.

# %%
# number of pateints of each disease with respect to state.
# making new data frame by joining two columns.
df['diagnosis-state']= df['state']+' '+df['diagnosis']
df['diagnosis-state'].value_counts()
# Out:
# benign lung cancer(large cell carcinoma)                    93
# malignant lung cancer                                       56
# malignant lung cancer(adenocarcinoma)                       23
# benign tuberculoma                                          14
# benign granuloma                                             8
# malignant lung cancer(bronchioloalveolar cell carcinoma)     7
# benign inflammatory mass                                     4
# benign unknown                                               4
# malignant metastasis of colon cancer                         4
# benign pulmonary tuberculosis                                3
# benign sclerosing hemangioma                                 2
# benign susp. inflammatory mass                               2
# benign pulmonary hematoma                                    2
# benign Inflammatory mass                                     2
# malignant lung cancer(squamous cell carcinoma)               2
# ...

# %%
# storing labels of newly made data frame into a list.
mylabels = df['diagnosis-state'].value_counts().index.tolist()
mylabels
# Out:
# ['benign lung cancer(large cell carcinoma)',
#  'malignant lung cancer',
#  'malignant lung cancer(adenocarcinoma)',
#  'benign tuberculoma',
#  'benign granuloma',
#  'malignant lung cancer(bronchioloalveolar cell carcinoma)',
#  'benign inflammatory mass',
#  'benign unknown',
#  'malignant metastasis of colon cancer',
#  'benign pulmonary tuberculosis',
#  'benign sclerosing hemangioma',
#  'benign susp. inflammatory mass',
#  'benign pulmonary hematoma',
#  'benign Inflammatory mass',
#  'malignant lung cancer(squamous cell carcinoma)',
#  'benign Cryptococcosis',
#  'benign lung abscess',
#  'benign hamartoma',
#  'benign susp. sclerosing hemangioma',
#  'malignant metastatic lung cancer',
#  'malignant susp. lung metastasis',
#  'benign susp. hamartoma',
#  'malignant metastasis of uterine cancer',
#  'benign organizing pneumonia',
#  'malignant metastasis of ovarian cancer',
#  'benign pneumonia',
#  'malignant lung cancer(large cell carcinoma)',
# ...

# %%
# pie chart of number of pateints of each disease with respect to state
plt.pyplot.pie(df['diagnosis-state'].value_counts(),labels=mylabels,autopct='%1.1f%%',radius=5)
# Out:
# ([<matplotlib.patches.Wedge at 0x145a981f5e0>,
# ...
#  [Text(2.080498940300977, 5.091318508933272, 'benign lung cancer(large cell carcinoma)'),
#   Text(-5.488881859718373, 0.34953673634480653, 'malignant lung cancer'),
#   Text(-3.238475733334451, -4.445478031056266, 'malignant lung cancer(adenocarcinoma)'),
#   Text(-0.8707520165775554, -5.430634486468973, 'benign tuberculoma'),
#   Text(0.662951702081767, -5.459898812313914, 'benign granuloma'),
#   Text(1.6862818213992463, -5.235117345276842, 'malignant lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(2.3998574087065037, -4.9488063629401084, 'benign inflammatory mass'),
#   Text(2.8901271362145895, -4.67944068629105, 'benign unknown'),
#   Text(3.350499833835926, -4.361668357803632, 'malignant metastasis of colon cancer'),
#   Text(3.725048654534672, -4.046481498950592, 'benign pulmonary tuberculosis'),
#   Text(3.9746810880803087, -3.801566814887874, 'benign sclerosing hemangioma'),
# ...

# %% [markdown]
# # QUESTION: 3

# %%
# number of pateints of each disease with respect to Gender.
# making new data frame by joining two columns.
df['diagnosis-gender']= df['diagnosis']+' ('+df['gender']+')'
df['diagnosis-gender'].value_counts()
# Out:
# lung cancer(large cell carcinoma) (Male)                   52
# lung cancer(large cell carcinoma) (Female)                 42
# lung cancer (Female)                                       32
# lung cancer (Male)                                         24
# lung cancer(adenocarcinoma) (Female)                       15
# tuberculoma (Male)                                          9
# lung cancer(adenocarcinoma) (Male)                          8
# granuloma (Male)                                            6
# tuberculoma (Female)                                        5
# lung cancer(bronchioloalveolar cell carcinoma) (Female)     4
# unknown (Female)                                            4
# pulmonary tuberculosis (Male)                               3
# metastasis of colon cancer (Female)                         3
# lung cancer(bronchioloalveolar cell carcinoma) (Male)       3
# hamartoma (Female)                                          2
# ...

# %%
# storing labels of newly made data frame into a list.
mylabels = df['diagnosis-gender'].value_counts().index.tolist()
mylabels
# Out:
# ['lung cancer(large cell carcinoma) (Male)',
#  'lung cancer(large cell carcinoma) (Female)',
#  'lung cancer (Female)',
#  'lung cancer (Male)',
#  'lung cancer(adenocarcinoma) (Female)',
#  'tuberculoma (Male)',
#  'lung cancer(adenocarcinoma) (Male)',
#  'granuloma (Male)',
#  'tuberculoma (Female)',
#  'lung cancer(bronchioloalveolar cell carcinoma) (Female)',
#  'unknown (Female)',
#  'pulmonary tuberculosis (Male)',
#  'metastasis of colon cancer (Female)',
#  'lung cancer(bronchioloalveolar cell carcinoma) (Male)',
#  'hamartoma (Female)',
#  'inflammatory mass (Male)',
#  'Inflammatory mass (Female)',
#  'Cryptococcosis (Female)',
#  'lung cancer(squamous cell carcinoma) (Male)',
#  'sclerosing hemangioma (Female)',
#  'inflammatory mass (Female)',
#  'granuloma (Female)',
#  'metastatic lung cancer (Female)',
#  'susp. inflammatory mass (Female)',
#  'organizing pneumonia (Female)',
#  'metastasis of ovarian cancer (Female)',
#  'metastasis of uterine cancer (Female)',
# ...

# %%
# pie chart of number of pateints of each disease with respect to Gender
plt.pyplot.pie(df['diagnosis-gender'].value_counts(),labels=mylabels,autopct='%1.1f%%',radius=5)
# Out:
# ([<matplotlib.patches.Wedge at 0x145a9e362e0>,
# ...
#  [Text(4.340272785033475, 3.37816994118084, 'lung cancer(large cell carcinoma) (Male)'),
#   Text(-1.5525798429466122, 5.276314606927441, 'lung cancer(large cell carcinoma) (Female)'),
#   Text(-5.178860555252213, 1.8518648301786866, 'lung cancer (Female)'),
#   Text(-5.130082219420042, -1.982991785658815, 'lung cancer (Male)'),
#   Text(-3.5679728672435593, -4.185638495930314, 'lung cancer(adenocarcinoma) (Female)'),
#   Text(-2.14508513510278, -5.06444565210854, 'tuberculoma (Male)'),
#   Text(-1.0085995256300067, -5.406729787671928, 'lung cancer(adenocarcinoma) (Male)'),
#   Text(-0.03497668137636266, -5.499888783580983, 'granuloma (Male)'),
#   Text(0.7323410205322997, -5.45102528242584, 'tuberculoma (Female)'),
#   Text(1.3501705011205234, -5.331701381163798, 'lung cancer(bronchioloalveolar cell carcinoma) (Female)'),
#   Text(1.8847626279469898, -5.166978791933866, 'unknown (Female)'),
# ...
